# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pylab
import scipy.stats as stat
from scipy.stats import ttest_ind, chi2_contingency
import statsmodels.api as sm
from statsmodels.formula.api import ols
from category_encoders import TargetEncoder
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
import pickle
import os

# %%
df = pd.read_csv("CDSPP_FS.csv")
df
# Out:
#                                      name    year  selling_price    fuel  \
# 0                           Maruti 800 AC  2007.0        60000.0  Petrol
# 1                Maruti Wagon R LXI Minor  2007.0       135000.0  Petrol
# 2                    Hyundai Verna 1.6 SX  2012.0       600000.0  Diesel
# 3                  Datsun RediGO T Option  2017.0       250000.0  Petrol
# 4                   Honda Amaze VX i-DTEC  2014.0       450000.0  Diesel
# ...                                   ...     ...            ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0       409999.0  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi  2014.0       409999.0  Diesel
# 4337                  Maruti 800 AC BSIII  2009.0       110000.0  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016.0       865000.0  Diesel
# 4339                     Renault KWID RXT  2016.0       225000.0  Petrol
#
#      seller_type transmission
# 0     Individual       Manual
# 1     Individual       Manual
# 2     Individual       Manual
# 3     Individual       Manual
# 4     Individual       Manual
# ...          ...          ...
# 4335  Individual       Manual
# 4336  Individual       Manual
# 4337  Individual       Manual
# 4338  Individual       Manual
# 4339  Individual       Manual
#
# [4340 rows x 6 columns]

# %% [markdown]
# ## Checking datatypes

# %%
df.dtypes
# Out:
# name              object
# year             float64
# selling_price    float64
# fuel              object
# seller_type       object
# transmission      object
# dtype: object

# %%
categorical = []
continuous = []
for column in df.columns:
    if df[column].dtypes == "int64" or df[column].dtypes == "float64":
        continuous.append(column)
    if df[column].dtypes == "object":
        categorical.append(column)

# %%
categorical,continuous
# Out:
# (['name', 'fuel', 'seller_type', 'transmission'], ['year', 'selling_price'])

# %% [markdown]
# ## Checking Categorical Variables

# %%
df.shape
# Out:
# (4340, 6)

# %%
len(df['name'].unique())
# Out:
# 1491

# %%
len(df['fuel'].unique())
# Out:
# 5

# %%
len(df['seller_type'].unique())
# Out:
# 3

# %%
len(df['transmission'].unique())
# Out:
# 2

# %% [markdown]
# ## Encoding Categorical Variables

# %% [markdown]
# ### Transmission Variable

# %%
le = LabelEncoder()
df['transmission_le'] = le.fit_transform(df['transmission'])

# %%
pickle.dump(le, open('transmission_le.pkl','wb'))

# %%
df.drop(['transmission'], axis=1, inplace=True)

# %%
df
# Out:
#                                      name    year  selling_price    fuel  \
# 0                           Maruti 800 AC  2007.0        60000.0  Petrol
# 1                Maruti Wagon R LXI Minor  2007.0       135000.0  Petrol
# 2                    Hyundai Verna 1.6 SX  2012.0       600000.0  Diesel
# 3                  Datsun RediGO T Option  2017.0       250000.0  Petrol
# 4                   Honda Amaze VX i-DTEC  2014.0       450000.0  Diesel
# ...                                   ...     ...            ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0       409999.0  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi  2014.0       409999.0  Diesel
# 4337                  Maruti 800 AC BSIII  2009.0       110000.0  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016.0       865000.0  Diesel
# 4339                     Renault KWID RXT  2016.0       225000.0  Petrol
#
#      seller_type  transmission_le
# 0     Individual                1
# 1     Individual                1
# 2     Individual                1
# 3     Individual                1
# 4     Individual                1
# ...          ...              ...
# 4335  Individual                1
# 4336  Individual                1
# 4337  Individual                1
# 4338  Individual                1
# 4339  Individual                1
#
# [4340 rows x 6 columns]

# %% [markdown]
# ### Seller_type Variable

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
ohe_df = pd.get_dummies(df['seller_type'])
ohe_df.drop(['Trustmark Dealer'], axis=1, inplace=True)

# %%
ohe_df
# Out:
#       Dealer  Individual
# 0      False        True
# 1      False        True
# 2      False        True
# 3      False        True
# 4      False        True
# ...      ...         ...
# 4335   False        True
# 4336   False        True
# 4337   False        True
# 4338   False        True
# 4339   False        True
#
# [4340 rows x 2 columns]

# %%
df = pd.concat([df, ohe_df], axis=1)

# %%
df
# Out:
#                                      name    year  selling_price    fuel  \
# 0                           Maruti 800 AC  2007.0        60000.0  Petrol
# 1                Maruti Wagon R LXI Minor  2007.0       135000.0  Petrol
# 2                    Hyundai Verna 1.6 SX  2012.0       600000.0  Diesel
# 3                  Datsun RediGO T Option  2017.0       250000.0  Petrol
# 4                   Honda Amaze VX i-DTEC  2014.0       450000.0  Diesel
# ...                                   ...     ...            ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0       409999.0  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi  2014.0       409999.0  Diesel
# 4337                  Maruti 800 AC BSIII  2009.0       110000.0  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016.0       865000.0  Diesel
# 4339                     Renault KWID RXT  2016.0       225000.0  Petrol
#
#      seller_type  transmission_le  Dealer  Individual
# 0     Individual                1   False        True
# 1     Individual                1   False        True
# 2     Individual                1   False        True
# 3     Individual                1   False        True
# 4     Individual                1   False        True
# ...          ...              ...     ...         ...
# 4335  Individual                1   False        True
# 4336  Individual                1   False        True
# 4337  Individual                1   False        True
# 4338  Individual                1   False        True
# 4339  Individual                1   False        True
#
# [4340 rows x 8 columns]

# %%
df.drop(['seller_type'], axis=1, inplace=True)

# %% [markdown]
# ## fuel Variable

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
ohe_df = pd.get_dummies(df['fuel'])

# %%
ohe_df
# Out:
#         CNG  Diesel  Electric    LPG  Petrol
# 0     False   False     False  False    True
# 1     False   False     False  False    True
# 2     False    True     False  False   False
# 3     False   False     False  False    True
# 4     False    True     False  False   False
# ...     ...     ...       ...    ...     ...
# 4335  False    True     False  False   False
# 4336  False    True     False  False   False
# 4337  False   False     False  False    True
# 4338  False    True     False  False   False
# 4339  False   False     False  False    True
#
# [4340 rows x 5 columns]

# %%
ohe_df.drop(['Electric'], axis=1, inplace=True)

# %%
ohe_df
# Out:
#         CNG  Diesel    LPG  Petrol
# 0     False   False  False    True
# 1     False   False  False    True
# 2     False    True  False   False
# 3     False   False  False    True
# 4     False    True  False   False
# ...     ...     ...    ...     ...
# 4335  False    True  False   False
# 4336  False    True  False   False
# 4337  False   False  False    True
# 4338  False    True  False   False
# 4339  False   False  False    True
#
# [4340 rows x 4 columns]

# %%
df = pd.concat([df, ohe_df], axis=1)

# %%
df
# Out:
#                                      name    year  selling_price    fuel  \
# 0                           Maruti 800 AC  2007.0        60000.0  Petrol
# 1                Maruti Wagon R LXI Minor  2007.0       135000.0  Petrol
# 2                    Hyundai Verna 1.6 SX  2012.0       600000.0  Diesel
# 3                  Datsun RediGO T Option  2017.0       250000.0  Petrol
# 4                   Honda Amaze VX i-DTEC  2014.0       450000.0  Diesel
# ...                                   ...     ...            ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0       409999.0  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi  2014.0       409999.0  Diesel
# 4337                  Maruti 800 AC BSIII  2009.0       110000.0  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016.0       865000.0  Diesel
# 4339                     Renault KWID RXT  2016.0       225000.0  Petrol
#
#       transmission_le  Dealer  Individual    CNG  Diesel    LPG  Petrol
# 0                   1   False        True  False   False  False    True
# 1                   1   False        True  False   False  False    True
# 2                   1   False        True  False    True  False   False
# 3                   1   False        True  False   False  False    True
# 4                   1   False        True  False    True  False   False
# ...               ...     ...         ...    ...     ...    ...     ...
# 4335                1   False        True  False    True  False   False
# 4336                1   False        True  False    True  False   False
# 4337                1   False        True  False   False  False    True
# 4338                1   False        True  False    True  False   False
# 4339                1   False        True  False   False  False    True
#
# [4340 rows x 11 columns]

# %%
df.drop(['fuel'], axis=1, inplace=True)

# %%
df["name"]
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %% [markdown]
# ### name Variable

# %%
name = df.name.value_counts().sort_values(ascending=False)

# %%
name.head(10)
# Out:
# name
# Maruti Swift Dzire VDI      69
# Maruti Alto 800 LXI         59
# Maruti Alto LXi             47
# Maruti Alto LX              35
# Hyundai EON Era Plus        35
# Maruti Swift VDI BSIV       29
# Maruti Wagon R VXI BS IV    29
# Maruti Swift VDI            27
# Hyundai EON Magna Plus      24
# Maruti Wagon R LXI Minor    24
# Name: count, dtype: int64

# %%
te = TargetEncoder()
te.fit(X=df['name'],y=df['selling_price'])
values = te.transform(df['name'])
df.drop(['name'], axis=1, inplace=True)
df = pd.concat([df,values],axis=1)

# %%
pickle.dump(te, open('name_te.pkl','wb'))

# %%
df["name"]
# Out:
# 0       224146.532596
# 1       246727.151575
# 2       433829.675684
# 3       363086.200111
# 4       432122.108112
#             ...
# 4335    394183.481274
# 4336    400741.144459
# 4337    332888.963315
# 4338    463852.529491
# 4339    335821.837196
# Name: name, Length: 4340, dtype: float64

# %%
df
# Out:
#         year  selling_price  transmission_le  Dealer  Individual    CNG  \
# 0     2007.0        60000.0                1   False        True  False
# 1     2007.0       135000.0                1   False        True  False
# 2     2012.0       600000.0                1   False        True  False
# 3     2017.0       250000.0                1   False        True  False
# 4     2014.0       450000.0                1   False        True  False
# ...      ...            ...              ...     ...         ...    ...
# 4335  2014.0       409999.0                1   False        True  False
# 4336  2014.0       409999.0                1   False        True  False
# 4337  2009.0       110000.0                1   False        True  False
# 4338  2016.0       865000.0                1   False        True  False
# 4339  2016.0       225000.0                1   False        True  False
#
#       Diesel    LPG  Petrol           name
# 0      False  False    True  224146.532596
# 1      False  False    True  246727.151575
# 2       True  False   False  433829.675684
# 3      False  False    True  363086.200111
# 4       True  False   False  432122.108112
# ...      ...    ...     ...            ...
# 4335    True  False   False  394183.481274
# 4336    True  False   False  400741.144459
# 4337   False  False    True  332888.963315
# 4338    True  False   False  463852.529491
# 4339   False  False    True  335821.837196
#
# [4340 rows x 10 columns]

# %% [markdown]
# ## Seperating dependent and independent variables

# %%
df_Y = df['selling_price']
df_Y
# Out:
# 0        60000.0
# 1       135000.0
# 2       600000.0
# 3       250000.0
# 4       450000.0
#           ...
# 4335    409999.0
# 4336    409999.0
# 4337    110000.0
# 4338    865000.0
# 4339    225000.0
# Name: selling_price, Length: 4340, dtype: float64

# %%
df_X = df.iloc[:,[0,2,3,4,5,6,7,8,9]]
df_X
# Out:
#         year  transmission_le  Dealer  Individual    CNG  Diesel    LPG  \
# 0     2007.0                1   False        True  False   False  False
# 1     2007.0                1   False        True  False   False  False
# 2     2012.0                1   False        True  False    True  False
# 3     2017.0                1   False        True  False   False  False
# 4     2014.0                1   False        True  False    True  False
# ...      ...              ...     ...         ...    ...     ...    ...
# 4335  2014.0                1   False        True  False    True  False
# 4336  2014.0                1   False        True  False    True  False
# 4337  2009.0                1   False        True  False   False  False
# 4338  2016.0                1   False        True  False    True  False
# 4339  2016.0                1   False        True  False   False  False
#
#       Petrol           name
# 0       True  224146.532596
# 1       True  246727.151575
# 2      False  433829.675684
# 3       True  363086.200111
# 4      False  432122.108112
# ...      ...            ...
# 4335   False  394183.481274
# 4336   False  400741.144459
# 4337    True  332888.963315
# 4338   False  463852.529491
# 4339    True  335821.837196
#
# [4340 rows x 9 columns]

# %%
df_X.columns
# Out:
# Index(['year', 'transmission_le', 'Dealer', 'Individual', 'CNG', 'Diesel',
#        'LPG', 'Petrol', 'name'],
#       dtype='object')

# %% [markdown]
# ## Scaling the dataset

# %%
scaler = StandardScaler()
df_X_scaled = pd.DataFrame(scaler.fit_transform(df_X),columns=df_X.columns)

# %%
pickle.dump(scaler, open('slr.pkl','wb'))

# %%
df_X_scaled
# Out:
#           year  transmission_le    Dealer  Individual       CNG    Diesel  \
# 0    -1.719855         0.339276 -0.545042    0.581253 -0.096449 -0.992196
# 1    -1.719855         0.339276 -0.545042    0.581253 -0.096449 -0.992196
# 2    -0.374549         0.339276 -0.545042    0.581253 -0.096449  1.007865
# 3     0.970757         0.339276 -0.545042    0.581253 -0.096449 -0.992196
# 4     0.163574         0.339276 -0.545042    0.581253 -0.096449  1.007865
# ...        ...              ...       ...         ...       ...       ...
# 4335  0.163574         0.339276 -0.545042    0.581253 -0.096449  1.007865
# 4336  0.163574         0.339276 -0.545042    0.581253 -0.096449  1.007865
# 4337 -1.181733         0.339276 -0.545042    0.581253 -0.096449 -0.992196
# 4338  0.701696         0.339276 -0.545042    0.581253 -0.096449  1.007865
# 4339  0.701696         0.339276 -0.545042    0.581253 -0.096449 -0.992196
#
#            LPG    Petrol      name
# 0    -0.072992  1.021899 -2.498450
# 1    -0.072992  1.021899 -2.159653
# 2    -0.072992 -0.978571  0.647611
# 3    -0.072992  1.021899 -0.413815
# 4    -0.072992 -0.978571  0.621991
# ...        ...       ...       ...
# 4335 -0.072992 -0.978571  0.052765
# 4336 -0.072992 -0.978571  0.151155
# 4337 -0.072992  1.021899 -0.866891
# 4338 -0.072992 -0.978571  1.098071
# 4339 -0.072992  1.021899 -0.822887
#
# [4340 rows x 9 columns]

# %%
df_scaled = pd.concat([df_X_scaled, df_Y], axis=1)

# %%
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    df[feature].hist(color="MEDIUMVIOLETRED")
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
    plt.show

# %%
plot_data(df_X_scaled,'year')

# %% [markdown]
# ## Exporting Transformed Dataset

# %%
df_scaled.to_csv('CDSPP_FT.csv', encoding='utf-8', index=False)
